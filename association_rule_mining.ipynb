# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ## Retrieve data

# %%
loan_df = pd.read_csv('data/loan_data.csv')
# Out:
# /var/folders/00/tjkdz9ts6d5_l28wxgwr3nm40000gn/T/ipykernel_68118/599935324.py:1: DtypeWarning: Columns (0: DaysLate, 1: AgencyTxnRecency, 2: DaysSinceLastTransaction) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_df = pd.read_csv('data/loan_data.csv')

# %%
loan_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 85171 entries, 0 to 85170
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DaysLate                      5907 non-null   object
#  1   EmploymentStatus              18948 non-null  str
#  2   IncomeAmount (GHS)            13867 non-null  str
#  3   SalaryMonthCount              13867 non-null  float64
#  4   HasConsistentSalaryAmount     13867 non-null  str
#  5   ClientTenure                  84263 non-null  str
#  6   LoanCycle                     85036 non-null  float64
#  7   LoanCycleDeviation            6171 non-null   float64
#  8   AccountArrearsConsistency     2503 non-null   object
#  9   InstalmentArrearsConsistency  2500 non-null   object
#  10  NetInflow                     65662 non-null  str
#  11  AverageDailyBalance           85135 non-null  str
#  12  ClientTier                    83846 non-null  str
# ...
